# %% [markdown]
# # 00 - preliminary-experiments
#
# **purpose**:
#
#
# **input**: `data/samples/`
#
#
# **output**: `docs/03-deliverables/01-midterm-report/05-preliminary-experiments-and-results.md`
