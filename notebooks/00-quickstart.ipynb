# %% [markdown]
# # project notebook overview
#
# use this notebook as the starting point for the project. define the problem, the data flow, the modeling plan, and the expected output before writing any code.

# %% [markdown]
# # Quick Start

# %% [markdown]
# **check gpu availability**. we import torch and check if a cuda-capable gpu is available. if so we use it for training (faster), otherwise we fall back to cpu. note that the project goal is cpu inference - gpu is only used to speed up model training.

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

if torch.cuda.is_available():
    print("GPU Name:", torch.cuda.get_device_name(0))
# Out:
# Using device: cuda
# GPU Name: NVIDIA RTX 5000 Ada Generation
